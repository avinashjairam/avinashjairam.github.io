# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashjairam/avinashjairam.github.io/blob/master/Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import requests,json
import requests
import json

# %%
#Client ID and SECRET - USE YOUR OWN!
CLIENT_ID = ''
CLIENT_SECRET = ''

AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

#creating the headers
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

#justin beiber's spotify link - https://open.spotify.com/artist/ 1uNFoZAHBGtllmzznpCI3s ?si=IFvzRkqJSaaaKFjM-yAiLg

# %%
#JUSTIN BEIBER'S ARTIST ID
artist_id = '1uNFoZAHBGtllmzznpCI3s'

# actual GET request with proper header
r = requests.get(BASE_URL + 'artists/' + artist_id  + '/albums', headers=headers)

# %%
#extracting the json and printing it as a string
#On your own - you need to write python code to parse the JSON returned and extract information
#read the spotify web api documentation to learn more about what is returned

data = r.json()

formatted_json = json.dumps(data, sort_keys=True, indent=10)
print(formatted_json)
# Out:
# {
#           "href": "https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s/albums?offset=0&limit=20&include_groups=album,single,compilation,appears_on",
#           "items": [
#                     {
#                               "album_group": "album",
#                               "album_type": "album",
#                               "artists": [
#                                         {
#                                                   "external_urls": {
#                                                             "spotify": "https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s"
#                                                   },
#                                                   "href": "https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s",
#                                                   "id": "1uNFoZAHBGtllmzznpCI3s",
#                                                   "name": "Justin Bieber",
# ...

# %%
#TAYLOR SWIFT

#https://open.spotify.com/artist/ 06HL4z0CvFAxyc27GXpf02 ?si=gKjb81YERUystI2USO-fhA


artist_id = '06HL4z0CvFAxyc27GXpf02'

# actual GET request with proper header
r = requests.get(BASE_URL + 'artists/' + artist_id  + '/albums', headers=headers)

data = r.json()
#printing the formatted json
#On your own - you need to write python code to parse the JSON returned and extract information
#read the spotify web api documentation to learn more about what is returned
formatted_json = json.dumps(data, sort_keys=True, indent=10)
print(formatted_json)
# Out:
# {
#           "href": "https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02/albums?offset=0&limit=20&include_groups=album,single,compilation,appears_on",
#           "items": [
#                     {
#                               "album_group": "album",
#                               "album_type": "album",
#                               "artists": [
#                                         {
#                                                   "external_urls": {
#                                                             "spotify": "https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02"
#                                                   },
#                                                   "href": "https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02",
#                                                   "id": "06HL4z0CvFAxyc27GXpf02",
#                                                   "name": "Taylor Swift",
# ...

# %%
#Getting data about a particular song

#baby shark spotify url - https://open.spotify.com/track/ 5ygDXis42ncn6kYG14lEVG ?si=ba408e6e97e34f0f
track_id = '5ygDXis42ncn6kYG14lEVG'

# actual GET request with proper header
r = requests.get(BASE_URL + 'audio-analysis/' + track_id, headers=headers)

#extracting the json
data = r.json()

#printing the formatted json
#On your own - you need to write python code to parse the JSON returned and extract information
#read the spotify web api documentation to learn more about what is returned
formatted_json = json.dumps(data, sort_keys=True, indent=10)
print(formatted_json)
# Out:
# {
#           "bars": [
#                     {
#                               "confidence": 0.802,
#                               "duration": 2.08699,
#                               "start": 1.26956
#                     },
#                     {
#                               "confidence": 0.26,
#                               "duration": 2.09443,
#                               "start": 3.35655
#                     },
#                     {
#                               "confidence": 0.571,
#                               "duration": 2.09086,
#                               "start": 5.45098
#                     },
#                     {
#                               "confidence": 0.85,
#                               "duration": 2.08399,
#                               "start": 7.54184
#                     },
#                     {
#                               "confidence": 0.344,
#                               "duration": 2.07841,
# ...

# %%
#Getting data about tracks in a playlist

#playlist link - https://open.spotify.com/playlist/ 1PVdQLrXE9S7XtgEDfwVID ?si=f9b6e5d4ef2e4a95

playlist_id = '1PVdQLrXE9S7XtgEDfwVID'

# actual GET request with proper header
r = requests.get(BASE_URL + 'playlists/' + playlist_id +'/tracks' , headers=headers)

#extracting the json

data = r.json()

#printing the formatted json 
#On your own - you need to write python code to parse the JSON returned and extract information
#read the spotify web api documentation to learn more about what is returned
formatted_json = json.dumps(data, sort_keys=True, indent=10)
print(formatted_json)
# Out:
# {
#           "href": "https://api.spotify.com/v1/playlists/1PVdQLrXE9S7XtgEDfwVID/tracks?offset=0&limit=100",
#           "items": [
#                     {
#                               "added_at": "2021-12-04T08:26:43Z",
#                               "added_by": {
#                                         "external_urls": {
#                                                   "spotify": "https://open.spotify.com/user/31tyqjldie6bpoq5zd6xkxwiesuq"
#                                         },
#                                         "href": "https://api.spotify.com/v1/users/31tyqjldie6bpoq5zd6xkxwiesuq",
#                                         "id": "31tyqjldie6bpoq5zd6xkxwiesuq",
#                                         "type": "user",
#                                         "uri": "spotify:user:31tyqjldie6bpoq5zd6xkxwiesuq"
#                               },
#                               "is_local": false,
#                               "primary_color": null,
# ...
